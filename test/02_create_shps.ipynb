# %% [markdown]
# <br>
#
# # Introdução

# %%
import os
#import re
# import time
# import json
# import folium
# import random
# import requests
# import numpy as np
import pandas as pd
# import seaborn as sns
import geopandas as gpd
from folium import plugins
from osgeo import gdal, osr
from bs4 import BeautifulSoup
from tqdm.notebook import trange, tqdm

# %%
from paths import *

# %%
from open_geodata import geo

# %% [markdown]
# <br>
#
# ## Join Data

# %%
# Lê o arquivo csv com o nome dos municípios
df = pd.read_csv(
    os.path.join(output_path_tab, 'tab_municipio_cetesb.csv'),
)

# %%
gdf = geo.load_dataset('sp_250k_wgs84')
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_municipio    645 non-null    int64
#  1   municipio_nome  645 non-null    object
#  2   geometry        645 non-null    geometry
# dtypes: geometry(1), int64(1), object(1)
# memory usage: 15.2+ KB

# %%
# # Lê o arquivo csv com o nome dos municípios
# gdf = gpd.read_file(
#     'https://raw.githubusercontent.com/michelmetran/sp/main/data/shps/sp_250k_wgs84.geojson',
# )
gdf.drop(['municipio_nome'], axis=1, inplace=True)
# gdf['id_municipio'] = gdf['id_municipio'].astype(int)
gdf['geometry'] = gdf.simplify(0.0015)

# Merge
gdf = gdf.merge(
    df,
    on='id_municipio',
    how='left'
)

# Results
gdf.head()
# Out:
#    id_municipio                                           geometry  \
# 0       3500105  POLYGON ((-51.05425 -21.40465, -51.04624 -21.4...
# 1       3500204  POLYGON ((-49.65795 -21.20333, -49.65361 -21.2...
# 2       3500303  POLYGON ((-46.97640 -21.96818, -46.97399 -21.9...
# 3       3500402  POLYGON ((-46.73501 -21.81891, -46.72104 -21.8...
# 4       3500501  POLYGON ((-46.60614 -22.44173, -46.59592 -22.4...
#
#      municipio_nome                                     agencia  \
# 0        Adamantina                Agência Ambiental de Dracena
# 1            Adolfo  Agência Ambiental de São José do Rio Preto
# 2             Aguaí  Agência Ambiental de São João da Boa Vista
# 3    Águas da Prata  Agência Ambiental de São João da Boa Vista
# 4  Águas de Lindóia             Agência Ambiental de Mogi Guaçu
#
#                          endereco complemento numero  \
# 0               Rua Tomé de Souza         NaN    438
# 1  Avenida Floriano André Cabrera         NaN    NaN
# 2            Rua Marechal Deodoro         NaN    345
# 3            Rua Marechal Deodoro         NaN    345
# 4              Rua Hugo Pancieira         NaN    400
#
#                                           bairro         municipio_sede  \
# 0                                         Centro                Dracena
# 1  Residencial Cidade Jardim - Jardim São Marcos  São José do Rio Preto
# 2                                         Centro  São João da Boa Vista
# 3                                         Centro  São João da Boa Vista
# 4                                    Pedregulhal             Mogi Guaçu
#
#          cep        telefone             fax                        email  \
# 0  17900-000  (18) 3822-3166  (18) 3822-3166     dracena_cetesb@sp.gov.br
# 1  15081-490  (17) 3218-4300  (17) 3218-4300    riopreto_cetesb@sp.gov.br
# 2  13870-223  (19) 3633-1510  (19) 3633-1510  sjboavista_cetesb@sp.gov.br
# 3  13870-223  (19) 3633-1510  (19) 3633-1510  sjboavista_cetesb@sp.gov.br
# 4  13845-190  (19) 3818-0396  (19) 3818-0396   mogiguacu_cetesb@sp.gov.br
#
#                                                  url
# 0  https://licenciamento.cetesb.sp.gov.br/municip...
# 1  https://licenciamento.cetesb.sp.gov.br/municip...
# 2  https://licenciamento.cetesb.sp.gov.br/municip...
# 3  https://licenciamento.cetesb.sp.gov.br/municip...
# 4  https://licenciamento.cetesb.sp.gov.br/municip...

# %% [markdown]
# <br>
#
# ## Save geojson

# %%
gdf.to_file(
    os.path.join(output_path_geo, 'sp_cetesb.geojson'),
    driver='GeoJSON',
    encoding='utf-8'
)

gdf.to_file(
    os.path.join(output_path_geo, 'sp_cetesb.gpkg'),
    layer='sp_cetesb',
    driver='GPKG',
)

# Results
gdf.head()
# Out:
# /home/michel/Documents/conda/envs/pablocarreira-py39/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /home/michel/Documents/conda/envs/pablocarreira-py39/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
#    id_municipio                                           geometry  \
# 0       3500105  POLYGON ((-51.05425 -21.40465, -51.04624 -21.4...
# 1       3500204  POLYGON ((-49.65795 -21.20333, -49.65361 -21.2...
# 2       3500303  POLYGON ((-46.97640 -21.96818, -46.97399 -21.9...
# 3       3500402  POLYGON ((-46.73501 -21.81891, -46.72104 -21.8...
# 4       3500501  POLYGON ((-46.60614 -22.44173, -46.59592 -22.4...
#
#      municipio_nome                                     agencia  \
# 0        Adamantina                Agência Ambiental de Dracena
# 1            Adolfo  Agência Ambiental de São José do Rio Preto
# 2             Aguaí  Agência Ambiental de São João da Boa Vista
# 3    Águas da Prata  Agência Ambiental de São João da Boa Vista
# 4  Águas de Lindóia             Agência Ambiental de Mogi Guaçu
#
#                          endereco complemento numero  \
# 0               Rua Tomé de Souza         NaN    438
# 1  Avenida Floriano André Cabrera         NaN    NaN
# 2            Rua Marechal Deodoro         NaN    345
# 3            Rua Marechal Deodoro         NaN    345
# 4              Rua Hugo Pancieira         NaN    400
#
#                                           bairro         municipio_sede  \
# 0                                         Centro                Dracena
# 1  Residencial Cidade Jardim - Jardim São Marcos  São José do Rio Preto
# 2                                         Centro  São João da Boa Vista
# 3                                         Centro  São João da Boa Vista
# 4                                    Pedregulhal             Mogi Guaçu
#
#          cep        telefone             fax                        email  \
# 0  17900-000  (18) 3822-3166  (18) 3822-3166     dracena_cetesb@sp.gov.br
# 1  15081-490  (17) 3218-4300  (17) 3218-4300    riopreto_cetesb@sp.gov.br
# 2  13870-223  (19) 3633-1510  (19) 3633-1510  sjboavista_cetesb@sp.gov.br
# 3  13870-223  (19) 3633-1510  (19) 3633-1510  sjboavista_cetesb@sp.gov.br
# 4  13845-190  (19) 3818-0396  (19) 3818-0396   mogiguacu_cetesb@sp.gov.br
#
#                                                  url
# 0  https://licenciamento.cetesb.sp.gov.br/municip...
# 1  https://licenciamento.cetesb.sp.gov.br/municip...
# 2  https://licenciamento.cetesb.sp.gov.br/municip...
# 3  https://licenciamento.cetesb.sp.gov.br/municip...
# 4  https://licenciamento.cetesb.sp.gov.br/municip...
